# %%
import log as lg
import numpy as np
from player import Player
import config
from model import ResidualCNN
from connect import connect
from connect import ConnectState

# %%
def playMatches(game, EPISODES, log):
    #potentially add reading the neural network later, look into funcs.py on Foster's github
    player1NN = ResidualCNN(config.REG_CONST, config.LEARNING_RATE, game.input_shape, game.actionSize, config.HIDDEN_CNN_LAYERS)
    player1 = Player('Player 1', game.stateSize, game.actionSize, config.MCTS_SIMS, config.CPUCT, player1NN)
    
    player2NN = ResidualCNN(config.REG_CONST, config.LEARNING_RATE, game.input_shape, game.actionSize, config.HIDDEN_CNN_LAYERS)
    player2 = Player('Player 2', game.stateSize, game.actionSize, config.MCTS_SIMS, config.CPUCT, player2NN)
    
    #Foster's has a memory function here. (score, memory, points, sp_score)
    score, points, sp_score = playMatchesHelper(game, player1NN, player1, player2NN, player2, EPISODES, log)
    return (scores, points, sp_scores)

# %%
def playMatchesHelper(game, player1NN, player1, player2NN, player2, EPISODES, player1Starts=0):
    turn = 0
    done = False
    episode = 0
    state = game.reset()
    scores = {player1.name:0, "drawn": 0, player2.name:0}
    sp_scores = {'sp':0, "drawn": 0, 'nsp':0}
    points = {player1.name:[], player2.name:[]}
    
    while episode < EPISODES:
        log.info('------------------------------------------')
        log.info('------------ EPISODE %d OF %d ------------', episode+1, EPISODES)
        log.info('------------------------------------------')
        player1.mcts = None
        player2.mcts = None
        if player1Starts == 0:
            player1Starts = random.randint(0, 1)*2-1
        if player1Starts == 1:
            players = {1: player1, -1: player2}
        else:
            players = {1: player2, -1: player1}
            
            
        #have some code here for the first turn of the game.
        while not done:
            turn += 1
            action, pi, valMCTS, valNN = players[state.currentPlayer].act(state)
            log.info('ACTION: %d', action)
            game.printGame(state, log)
            log.info('MCTS VALUE FOR ACTION %f', valMCTS)
            log.info('NEURAL NET VALUE FOR ACTION %f', valNN)
            
            if done:
                if value == 1:
                    logger.info('%s WINS!', players[state.playerTurn].name)
                    scores[players[state.currentPlayer]['name']] = scores[players[state.currentPlayer].name] + 1
                    if state.currentPlayer == 1: 
                        sp_scores['sp'] = sp_scores['sp'] + 1
                    else:
                        sp_scores['nsp'] = sp_scores['nsp'] + 1

                elif value == -1:
                    logger.info('%s WINS!', players[-state.currentPlayer].name)
                    scores[players[-state.currentPlayer]['name']] = scores[players[-state.currentPlayer].name] + 1
               
                    if state.currentPlayer == 1: 
                        sp_scores['nsp'] = sp_scores['nsp'] + 1
                    else:
                        sp_scores['sp'] = sp_scores['sp'] + 1

                else:
                    logger.info('DRAW...')
                    scores['drawn'] = scores['drawn'] + 1
                    sp_scores['drawn'] = sp_scores['drawn'] + 1
            
            
        episode += 1
        
    return (scores, points, sp_scores)

# %%
lg.logger_main.info('=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*')
lg.logger_main.info('=*=*=*=*=*=.      NEW LOG      =*=*=*=*=*')
lg.logger_main.info('=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*')

# %%
# create an untrained neural network objects from the config file
current_NN = ResidualCNN(config.REG_CONST, config.LEARNING_RATE, (2,) + game.grid_shape,   game.actionSize, config.HIDDEN_CNN_LAYERS)
best_NN = ResidualCNN(config.REG_CONST, config.LEARNING_RATE, (2,) +  game.grid_shape,   game.actionSize, config.HIDDEN_CNN_LAYERS)


#not implementing loading a model at the moment. currently just trying to get this to run, then will implement building models from
#given files.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-1e54c6675955> in <module>
#       1 # create an untrained neural network objects from the config file
# ----> 2 current_NN = ResidualCNN(config.REG_CONST, config.LEARNING_RATE, (2,) + env.grid_shape,   env.action_size, config.HIDDEN_CNN_LAYERS)
#       3 best_NN = ResidualCNN(config.REG_CONST, config.LEARNING_RATE, (2,) +  env.grid_shape,   env.action_size, config.HIDDEN_CNN_LAYERS)
#
# NameError: name 'env' is not defined

# %%
game = connect()
EPISODES = config.EPISODES
log = lg.logger_main

# %%
scores, points, sp_points = playMatches(game, EPISODES, log)
# Out:
# /Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/logging/__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/logging/__init__.py", line 925, in format
#     return fmt.format(record)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/logging/__init__.py", line 664, in format
#     record.message = record.getMessage()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# ValueError: incomplete format
# Call stack:
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-edd7aeb0c0ab>", line 1, in <module>
#     scores, points, sp_points = playMatches(game, EPISODES, log)
#   File "<ipython-input-2-82c3faaa2050>", line 10, in playMatches
#     score, points, sp_score = playMatchesHelper(game, player1NN, player1, player2NN, player2, EPISODES, log)
#   File "<ipython-input-3-511e222ecf15>", line 27, in playMatchesHelper
#     action, pi, valMCTS, valNN = players[state.currentPlayer].act(state)
#   File "/Users/jeremylevitt/Desktop/WINTER_PROJECT/player.py", line 53, in act
#     self.newMCTS(state)
#   File "/Users/jeremylevitt/Desktop/WINTER_PROJECT/player.py", line 23, in newMCTS
#     lg.logger_mcts.info('%%%%%%%% NEW MCTS TREE FOR PLAYER %s %%%%%%%%%', self.name)
# Message: '%%%%%%%% NEW MCTS TREE FOR PLAYER %s %%%%%%%%%'
# Arguments: ('Player 2',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/logging/__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/logging/__init__.py", line 925, in format
#     return fmt.format(record)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/logging/__init__.py", line 664, in format
#     record.message = record.getMessage()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# ValueError: incomplete format
# Call stack:
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/jeremylevitt/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-edd7aeb0c0ab>", line 1, in <module>
#     scores, points, sp_points = playMatches(game, EPISODES, log)
#   File "<ipython-input-2-82c3faaa2050>", line 10, in playMatches
#     score, points, sp_score = playMatchesHelper(game, player1NN, player1, player2NN, player2, EPISODES, log)
#   File "<ipython-input-3-511e222ecf15>", line 27, in playMatchesHelper
#     action, pi, valMCTS, valNN = players[state.currentPlayer].act(state)
#   File "/Users/jeremylevitt/Desktop/WINTER_PROJECT/player.py", line 59, in act
#     lg.logger_mcts.info('%%SIMULATION NO. %d %', simulation+1)
# Message: '%%SIMULATION NO. %d %'
# Arguments: (1,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-edd7aeb0c0ab> in <module>
# ----> 1 scores, points, sp_points = playMatches(game, EPISODES, log)
#
# <ipython-input-2-82c3faaa2050> in playMatches(game, EPISODES, log)
#       8
#       9     #Foster's has a memory function here. (score, memory, points, sp_score)
# ---> 10     score, points, sp_score = playMatchesHelper(game, player1NN, player1, player2NN, player2, EPISODES, log)
#      11     return (scores, points, sp_scores)
#      12
#
# <ipython-input-3-511e222ecf15> in playMatchesHelper(game, player1NN, player1, player2NN, player2, EPISODES, player1Starts)
#      25         while not done:
#      26             turn += 1
# ---> 27             action, pi, valMCTS, valNN = players[state.currentPlayer].act(state)
#      28             log.info('ACTION: %d', action)
#      29             game.printGame(state)
#
# ~/Desktop/WINTER_PROJECT/player.py in act(self, state)
#      59             lg.logger_mcts.info('%%SIMULATION NO. %d %', simulation+1)
#      60             lg.logger_mcts.info('%%%%%%%%%%%%%%%%%%%%%')
# ---> 61             self.simulate()
#      62
#      63         pi, expVal = self.getPiandEV()
#
# ~/Desktop/WINTER_PROJECT/player.py in simulate(self)
#      84         value, pathTaken = self.expandTree(leaf, value, done, pathTaken)
#      85          #backpropogate.
# ---> 86         self.mcts.backFill(leaf, value, pathTaken)
#      87
#      88     def expandTree(self, leaf, value, done, pathTaken):
#
# TypeError: backFill() takes 3 positional arguments but 4 were given
